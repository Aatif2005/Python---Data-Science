# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
df = pd.read_csv(r"C:\Users\aatif\OneDrive\Desktop\TradeStat-Ftspcc-TotalTrade-Country-Wise.csv")
print(df)
# Out:
#      S.No             Country/Region  Exports_1  Imports_1  Total Trade_1  \
# 0       1                AFGHANISTAN    2380.99    4568.60        6949.58
# 1       2                    ALBANIA    9467.48      56.40        9523.88
# 2       3                    ALGERIA    5636.04    5462.03       11098.06
# 3       4                AMERI SAMOA       2.93       0.40           3.33
# 4       5                    ANDORRA       2.04       0.39           2.44
# 5       6                     ANGOLA    4487.02   20734.44       25221.47
# 6       7                   ANGUILLA       1.91       2.44           4.35
# 7       8                  ANTARTICA       2.15       3.70           5.85
# 8       9                    ANTIGUA     116.78       5.92         122.70
# 9      10                  ARGENTINA    7274.48   17117.95       24392.43
# 10     11                    ARMENIA     660.17     293.69         953.86
# 11     12                      ARUBA     101.57       8.36         109.93
# ...
