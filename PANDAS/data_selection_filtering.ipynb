# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\aatif\OneDrive\Desktop\Bollywood_Filmstars.csv")
print(df)
# Out:
#                Actor                     Movie  Year             Genre  \
# 0     Shah Rukh Khan                     Jawan  2023            Action
# 1        Salman Khan         Bajrangi Bhaijaan  2015             Drama
# 2         Aamir Khan                    Dangal  2016      Sports Drama
# 3      Ranbir Kapoor                    Animal  2023      Action Crime
# 4      Ranveer Singh                 Padmaavat  2018  Historical Drama
# 5     Hrithik Roshan                       War  2019            Action
# 6       Akshay Kumar              Sooryavanshi  2021            Action
# 7         Ajay Devgn                Drishyam 2  2022          Thriller
# 8   Deepika Padukone                  Chhapaak  2020             Drama
# 9         Alia Bhatt       Gangubai Kathiawadi  2022         Biography
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022     Horror Comedy
# 11     Vicky Kaushal  Uri: The Surgical Strike  2019               War
# ...

# %%
df['Actor'][5]
# Out:
# 'Hrithik Roshan'

# %%
df[['Actor','Genre']]
# Out:
#                Actor             Genre
# 0     Shah Rukh Khan            Action
# 1        Salman Khan             Drama
# 2         Aamir Khan      Sports Drama
# 3      Ranbir Kapoor      Action Crime
# 4      Ranveer Singh  Historical Drama
# 5     Hrithik Roshan            Action
# 6       Akshay Kumar            Action
# 7         Ajay Devgn          Thriller
# 8   Deepika Padukone             Drama
# 9         Alia Bhatt         Biography
# 10     Kartik Aaryan     Horror Comedy
# 11     Vicky Kaushal               War
# 12     Rajkummar Rao     Horror Comedy
# 13    Kareena Kapoor            Comedy
# 14      Kiara Advani         War Drama

# %%
df.loc[1]
# Out:
# Actor                            Salman Khan
# Movie                      Bajrangi Bhaijaan
# Year                                    2015
# Genre                                  Drama
# Box Office (INR Crores)                  969
# IMDb Rating                              8.1
# Name: 1, dtype: object

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
result = df.iloc[0:2, 0:2]
print(result)
# Out:
#             Actor              Movie
# 0  Shah Rukh Khan              Jawan
# 1     Salman Khan  Bajrangi Bhaijaan

# %%
df.loc[df['IMDb Rating'] > 7, 'Actor']
# Out:
# 1       Salman Khan
# 2        Aamir Khan
# 7        Ajay Devgn
# 9        Alia Bhatt
# 11    Vicky Kaushal
# 12    Rajkummar Rao
# 14     Kiara Advani
# Name: Actor, dtype: str

# %%
result = df[(df['IMDb Rating'] > 7) & (df['Year'] > 2018)]
print(result)
# Out:
#             Actor                     Movie  Year          Genre  \
# 7      Ajay Devgn                Drishyam 2  2022       Thriller
# 9      Alia Bhatt       Gangubai Kathiawadi  2022      Biography
# 11  Vicky Kaushal  Uri: The Surgical Strike  2019            War
# 12  Rajkummar Rao                   Stree 2  2024  Horror Comedy
# 14   Kiara Advani                 Shershaah  2021      War Drama
#
#     Box Office (INR Crores)  IMDb Rating
# 7                       345          8.2
# 9                       209          7.8
# 11                      342          8.2
# 12                      874          7.2
# 14                       70          8.3

# %%
quest = df.query("Year > 2018 and `IMDb Rating` > 7")
print(quest)
# Out:
#             Actor                     Movie  Year          Genre  \
# 7      Ajay Devgn                Drishyam 2  2022       Thriller
# 9      Alia Bhatt       Gangubai Kathiawadi  2022      Biography
# 11  Vicky Kaushal  Uri: The Surgical Strike  2019            War
# 12  Rajkummar Rao                   Stree 2  2024  Horror Comedy
# 14   Kiara Advani                 Shershaah  2021      War Drama
#
#     Box Office (INR Crores)  IMDb Rating
# 7                       345          8.2
# 9                       209          7.8
# 11                      342          8.2
# 12                      874          7.2
# 14                       70          8.3

# %%
df2 = df[['Actor','IMDb Rating']]
print(df2)
# Out:
#                Actor  IMDb Rating
# 0     Shah Rukh Khan          7.0
# 1        Salman Khan          8.1
# 2         Aamir Khan          8.3
# 3      Ranbir Kapoor          6.2
# 4      Ranveer Singh          7.0
# 5     Hrithik Roshan          6.5
# 6       Akshay Kumar          6.0
# 7         Ajay Devgn          8.2
# 8   Deepika Padukone          5.4
# 9         Alia Bhatt          7.8
# 10     Kartik Aaryan          5.7
# 11     Vicky Kaushal          8.2
# 12     Rajkummar Rao          7.2
# 13    Kareena Kapoor          6.4
# 14      Kiara Advani          8.3

# %%
df2.loc[0,'Actor'] = "Aatif"
print(df2)
# Out:
#                Actor  IMDb Rating
# 0              Aatif          7.0
# 1        Salman Khan          8.1
# 2         Aamir Khan          8.3
# 3      Ranbir Kapoor          6.2
# 4      Ranveer Singh          7.0
# 5     Hrithik Roshan          6.5
# 6       Akshay Kumar          6.0
# 7         Ajay Devgn          8.2
# 8   Deepika Padukone          5.4
# 9         Alia Bhatt          7.8
# 10     Kartik Aaryan          5.7
# 11     Vicky Kaushal          8.2
# 12     Rajkummar Rao          7.2
# 13    Kareena Kapoor          6.4
# 14      Kiara Advani          8.3
